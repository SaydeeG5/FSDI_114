# %%
# Pass by value 
# int, float, boolean, imaginarynumbers 

x = 5  # so 5 is copied 
y = x  # so changes here 5 this is a new copy 
x = x + 1

print (y)
print (id(x))
print (id(y))
# Out:
# 5
# 4317587040
# 4317587008

# %%
# pass by reference 
# Python lists (example):

x = [1,2,3,4,5]  # x and y are pointing to the same memory (modifying exact same copy)
y = x 
x.append(6)

print (y)
print (id(x))
print (id(y))
# Out:
# [1, 2, 3, 4, 5, 6]
# 4355318144
# 4355318144

# %%
# singly linked list , append , assert , remove .... index, length 

help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
class SinglyLinkedList: 
    class __Node: # nested class   thats why double underscore , not meatn to be used outside this class 
        def __init__(self, data): # 
            self.data = data
            self.next = None 
            
    def __init__(self):          # constructor 
        self.head = None         # everytime created default empty 
        
    def append(self, value):      # append at the tail 
        new_node = self.__Node(value)
        if not self.head:        # if head is empty? this is true when self.head = None(this happens everytime list is created )
            self.head = new_node # create head 
        else: 
            current = self.head  # traversing ; going through the nodes and checking them , link hopping or pointer hopping  
            while current.next:  # this is true as long as current.next does NOT equal None 
                current = current.next  # finding the tail 
            current.next = new_node     # found tail thats where we put the new node , the tail node 
            
        def __str__(self): 
            out = "["
            if self.head:
                out += "%s" % self.head.data  # %s this is formatting a string 
            current = self.head               # if my list is empty 22- 28 would be skipped 
            while current:                    
                current = current.next        # if we 
                if current:                   # if there is 
                        out += ", %s" % current.data
            out += "]"
            return out 
        
        def insert(self, index, value):
        
            pass
        
        def remove(self):
            # link out the current head and link it or point it to the second node 
            # remove that first node 
            pass

# %% [markdown]
#            def insert (self, index, value):
#
#             1. create new node
#             2. set its element to the new element
#             3. set its next link to refer to the current head
#             4. then set the list's head to point to the new node
#
#           1 & 2 new_node ->
#           3 new_node.next = head;
#           4 head = new.node
#
#
#           def insert (self, index, value):
#               new_node = self.__Node(value)
#               new_node.next  = self.head
#               self.head = new_node
#
#
#           def remove (self) :
#
#           1. is there a head -> if yes? -> return
#           2. else make the next node the head
#
#
#           def remove (self):
#
#           if self.head == None: return
#           self.head = self.head.next

# %%
sll = SinglyLinkedList()

print("Empty list:")
print(sll)

sll.append(0)
print("One element:")
print(sll)

print("More than one element:")
for number in range (1,5):
    sll.append(number)
    
print(sll)
# Out:
# Empty list:
# ...
# One element:
# ...
# More than one element:
# ...

# %% [markdown]
# # from the start its default empty (see line 7-8)
#
# # def append -> if not self.head: (this case its true because this is the first one)
#                #self.head = new_node (1) (create the head)
#
# # next find the tail , current = current.next; current.next = new_code (2)
#
# # next find the tail again ,current = current.next; current.next = new_code (3)
#
# # next find the tail again ,current = current.next; current.next = new_code (4)
#
#
#
# #a = SinglyLinkedList (1)
# #b = SinglyLinkedList (2)
# #c = SinglyLinkedList (3)
# #d = SinglyLinkedList (4)
#
# #a.new_node = b
# #b.new_node = c
# #c.new_node = d
